# %% [markdown]
# <a href="https://colab.research.google.com/github/PeterssonM/Degree-Project-in-Computer-Engineering/blob/master/fps_benchmark.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install ultralytics
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 721.3/721.3 kB 10.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23.7/23.7 MB 26.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 823.6/823.6 kB 64.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.1/14.1 MB 86.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 731.7/731.7 MB 2.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 410.6/410.6 MB 2.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 121.6/121.6 MB 12.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.5/56.5 MB 29.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 124.2/124.2 MB 5.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 196.0/196.0 MB 5.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 166.0/166.0 MB 5.9 MB/s eta 0:00:00
# ...

# %%
"""

MIT License

Copyright 2024 Maximilian Petersson and Nahom Solomon

"""



from ultralytics import YOLO
from cv2 import VideoCapture, VideoWriter, VideoWriter_fourcc
import time
import sys

model = YOLO('/content/last.pt')
#TRACKER = 'botsort.yaml'
TRACKER = 'bytetrack.yaml'

iterations = 11 #First iteration is warmup.

cumulative_min_fps = 0.0
cumulative_average_fps = 0.0
cumulative_max_fps = 0.0

for i in range(iterations):
  cap = VideoCapture('/content/v1imgz640 - TrimFINAL.mp4')
  out = VideoWriter('output.avi', VideoWriter_fourcc(*'XVID'), 30.0, (640, 640))

  frame_counter = 0

  min_fps = sys.float_info.max
  cumulative_fps = 0.0
  max_fps = sys.float_info.min

  while True:
    ret, frame = cap.read()
    if not ret:
      break

    start = time.time()
    output = model.track(frame, tracker=TRACKER, conf=0.257, persist=True, show=False)
    end = time.time()

    frame_counter += 1

    fps = 1.0 / (end - start)
    print("%.1f" % fps)

    min_fps = min(min_fps, fps)
    cumulative_fps += fps
    max_fps = max(max_fps, fps)

  if(i != 0): #First iteration is warmup.
    cumulative_min_fps += min_fps
    cumulative_average_fps += (cumulative_fps / frame_counter)
    cumulative_max_fps += max_fps

    cap.release()
    out.release()

print("Min FPS: %.1f" % (cumulative_min_fps / (iterations - 1)))
print("Average FPS: %.1f" % (cumulative_average_fps / (iterations - 1) ))
print("Max FPS: %.1f" % (cumulative_max_fps / (iterations - 1)))
# Out:
# Utdata för streaming har trunkerats till de sista 5000 raderna.
# 55.0
#
# 0: 640x640 13 cars, 7.8ms
# Speed: 1.5ms preprocess, 7.8ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 640)
# 52.4
#
# 0: 640x640 13 cars, 6.8ms
# Speed: 2.1ms preprocess, 6.8ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 640)
# 55.9
#
# 0: 640x640 13 cars, 7.8ms
# Speed: 1.5ms preprocess, 7.8ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 640)
# 58.1
#
# 0: 640x640 14 cars, 7.0ms
# Speed: 1.4ms preprocess, 7.0ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 640)
# 57.7
#
# 0: 640x640 14 cars, 7.1ms
# Speed: 1.8ms preprocess, 7.1ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 640)
# 57.3
#
# 0: 640x640 14 cars, 7.5ms
# Speed: 1.7ms preprocess, 7.5ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 640)
# 55.5
#
# 0: 640x640 14 cars, 7.1ms
# ...
